# %% [markdown]
# # Lets Generate the Model co-efficients from the matrices representation

# %%
# Lets import the linraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn  as sns

# %%
# Reading the dataset

df = pd.read_csv('https://cdn.upgrad.com/UpGrad/temp/098bb2e9-83fb-48df-9dd1-fac56fbb25ca/advertising.csv')

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# ### AS We are using the Simple linear regression, So we have to use only one single feature and 1 target variable that is Sales.
# ### So we are using our feature variable as TV

# %%
df = df[['TV', 'Sales']]

# %%
df
# Out:
#         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2   12.0
# 3    151.5   16.5
# 4    180.8   17.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2   14.0
# 197  177.0   14.8
# 198  283.6   25.5
# 199  232.1   18.4
#
# [200 rows x 2 columns]

# %%
# Plotting a scatter plot

sns.scatterplot( data = df , x = 'TV' , y = 'Sales')
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Sales'>

# %%
# Splitting the dataset into X and y

X = np.array(df['TV']).reshape(-1,1) # predictor variable
y = np.array(df['Sales']).reshape(-1,1) # response variable

# %% [markdown]
# ### Normal Equations
#
# #### Regression Equation
# $\hat{y_i} = b_{0} + b_{1}{x_i}$<br>
# where slope of trend line is calculated as:<br>
# $b_{1}=\frac{\sum (x_i-\bar{x})*(y_i-\bar{y})}{\sum (x_i-\bar{x})^{2}}$<br>
# and the intercept is computed as:<br>
# $b_{0}=\bar{y}-b_{1}\bar{x}$

# %%
# Computing X and Y
X = df['TV'].values # advertising spend on TV
Y = df['Sales'].values # Sales

# %%
 # Mean X and Y
mean_x = np.mean(X)
mean_y = np.mean(Y)
 
# Total number of values
n = len(X)

# %%
# Lets calculate bo and b1
nume = 0
deno = 0
for i in range(n):
    nume += (X[i] - mean_x)*(Y[i] - mean_y)
    deno += (X[i] - mean_x) ** 2

b1 = nume/deno
b0 = mean_y - (b1 * mean_x)
print('The co-efficients are :-', b0, b1)
# Out:
# The co-efficients are :- 6.974821488229903 0.05546477046955879

# %% [markdown]
# ### Linear Regression Model Estimates using Matrix Multiplications
#
# $\widehat{\beta}=(X^{T}.X)^{-1}.X^{T}.Y$

# %%
# We use NumPy’s vstack to create a 2-d numpy array from two 1d-arrays and create X_mat.
X_mat=np.vstack((np.ones(len(X)), X)).T

# %%
X_mat
# Out:
# array([[  1. , 230.1],
#        [  1. ,  44.5],
#        [  1. ,  17.2],
#        [  1. , 151.5],
#        [  1. , 180.8],
#        [  1. ,   8.7],
#        [  1. ,  57.5],
#        [  1. , 120.2],
#        [  1. ,   8.6],
#        [  1. , 199.8],
#        [  1. ,  66.1],
#        [  1. , 214.7],
#        [  1. ,  23.8],
#        [  1. ,  97.5],
#        [  1. , 204.1],
#        [  1. , 195.4],
#        [  1. ,  67.8],
#        [  1. , 281.4],
#        [  1. ,  69.2],
#        [  1. , 147.3],
#        [  1. , 218.4],
#        [  1. , 237.4],
#        [  1. ,  13.2],
#        [  1. , 228.3],
#        [  1. ,  62.3],
#        [  1. , 262.9],
#        [  1. , 142.9],
#        [  1. , 240.1],
#        [  1. , 248.8],
#        [  1. ,  70.6],
#        [  1. , 292.9],
#        [  1. , 112.9],
#        [  1. ,  97.2],
#        [  1. , 265.6],
#        [  1. ,  95.7],
#        [  1. , 290.7],
#        [  1. , 266.9],
#        [  1. ,  74.7],
#        [  1. ,  43.1],
#        [  1. , 228. ],
#        [  1. , 202.5],
#        [  1. , 177. ],
#        [  1. , 293.6],
#        [  1. , 206.9],
#        [  1. ,  25.1],
#        [  1. , 175.1],
#        [  1. ,  89.7],
#        [  1. , 239.9],
#        [  1. , 227.2],
#        [  1. ,  66.9],
#        [  1. , 199.8],
#        [  1. , 100.4],
#        [  1. , 216.4],
#        [  1. , 182.6],
#        [  1. , 262.7],
#        [  1. , 198.9],
#        [  1. ,   7.3],
#        [  1. , 136.2],
#        [  1. , 210.8],
#        [  1. , 210.7],
#        [  1. ,  53.5],
#        [  1. , 261.3],
#        [  1. , 239.3],
#        [  1. , 102.7],
#        [  1. , 131.1],
#        [  1. ,  69. ],
#        [  1. ,  31.5],
#        [  1. , 139.3],
#        [  1. , 237.4],
#        [  1. , 216.8],
#        [  1. , 199.1],
#        [  1. , 109.8],
#        [  1. ,  26.8],
#        [  1. , 129.4],
#        [  1. , 213.4],
#        [  1. ,  16.9],
#        [  1. ,  27.5],
#        [  1. , 120.5],
#        [  1. ,   5.4],
#        [  1. , 116. ],
#        [  1. ,  76.4],
#        [  1. , 239.8],
#        [  1. ,  75.3],
#        [  1. ,  68.4],
#        [  1. , 213.5],
#        [  1. , 193.2],
#        [  1. ,  76.3],
#        [  1. , 110.7],
#        [  1. ,  88.3],
#        [  1. , 109.8],
#        [  1. , 134.3],
#        [  1. ,  28.6],
#        [  1. , 217.7],
#        [  1. , 250.9],
#        [  1. , 107.4],
#        [  1. , 163.3],
#        [  1. , 197.6],
#        [  1. , 184.9],
#        [  1. , 289.7],
#        [  1. , 135.2],
#        [  1. , 222.4],
#        [  1. , 296.4],
#        [  1. , 280.2],
#        [  1. , 187.9],
#        [  1. , 238.2],
#        [  1. , 137.9],
#        [  1. ,  25. ],
#        [  1. ,  90.4],
#        [  1. ,  13.1],
#        [  1. , 255.4],
#        [  1. , 225.8],
#        [  1. , 241.7],
#        [  1. , 175.7],
#        [  1. , 209.6],
#        [  1. ,  78.2],
#        [  1. ,  75.1],
#        [  1. , 139.2],
#        [  1. ,  76.4],
#        [  1. , 125.7],
#        [  1. ,  19.4],
#        [  1. , 141.3],
#        [  1. ,  18.8],
#        [  1. , 224. ],
#        [  1. , 123.1],
#        [  1. , 229.5],
#        [  1. ,  87.2],
#        [  1. ,   7.8],
#        [  1. ,  80.2],
#        [  1. , 220.3],
#        [  1. ,  59.6],
#        [  1. ,   0.7],
#        [  1. , 265.2],
#        [  1. ,   8.4],
#        [  1. , 219.8],
#        [  1. ,  36.9],
#        [  1. ,  48.3],
#        [  1. ,  25.6],
#        [  1. , 273.7],
#        [  1. ,  43. ],
#        [  1. , 184.9],
#        [  1. ,  73.4],
#        [  1. , 193.7],
#        [  1. , 220.5],
#        [  1. , 104.6],
#        [  1. ,  96.2],
#        [  1. , 140.3],
#        [  1. , 240.1],
#        [  1. , 243.2],
#        [  1. ,  38. ],
#        [  1. ,  44.7],
#        [  1. , 280.7],
#        [  1. , 121. ],
#        [  1. , 197.6],
#        [  1. , 171.3],
#        [  1. , 187.8],
#        [  1. ,   4.1],
#        [  1. ,  93.9],
#        [  1. , 149.8],
#        [  1. ,  11.7],
#        [  1. , 131.7],
#        [  1. , 172.5],
#        [  1. ,  85.7],
#        [  1. , 188.4],
#        [  1. , 163.5],
#        [  1. , 117.2],
#        [  1. , 234.5],
#        [  1. ,  17.9],
#        [  1. , 206.8],
#        [  1. , 215.4],
#        [  1. , 284.3],
#        [  1. ,  50. ],
#        [  1. , 164.5],
#        [  1. ,  19.6],
#        [  1. , 168.4],
#        [  1. , 222.4],
#        [  1. , 276.9],
#        [  1. , 248.4],
#        [  1. , 170.2],
#        [  1. , 276.7],
#        [  1. , 165.6],
#        [  1. , 156.6],
#        [  1. , 218.5],
#        [  1. ,  56.2],
#        [  1. , 287.6],
#        [  1. , 253.8],
#        [  1. , 205. ],
#        [  1. , 139.5],
#        [  1. , 191.1],
#        [  1. , 286. ],
#        [  1. ,  18.7],
#        [  1. ,  39.5],
#        [  1. ,  75.5],
#        [  1. ,  17.2],
#        [  1. , 166.8],
#        [  1. , 149.7],
#        [  1. ,  38.2],
#        [  1. ,  94.2],
#        [  1. , 177. ],
#        [  1. , 283.6],
#        [  1. , 232.1]])

# %%
y
# Out:
# array([[22.1],
#        [10.4],
#        [12. ],
#        [16.5],
#        [17.9],
#        [ 7.2],
#        [11.8],
#        [13.2],
#        [ 4.8],
#        [15.6],
#        [12.6],
#        [17.4],
#        [ 9.2],
#        [13.7],
#        [19. ],
#        [22.4],
#        [12.5],
#        [24.4],
#        [11.3],
#        [14.6],
#        [18. ],
#        [17.5],
#        [ 5.6],
#        [20.5],
#        [ 9.7],
#        [17. ],
#        [15. ],
#        [20.9],
#        [18.9],
#        [10.5],
#        [21.4],
#        [11.9],
#        [13.2],
#        [17.4],
#        [11.9],
#        [17.8],
#        [25.4],
#        [14.7],
#        [10.1],
#        [21.5],
#        [16.6],
#        [17.1],
#        [20.7],
#        [17.9],
#        [ 8.5],
#        [16.1],
#        [10.6],
#        [23.2],
#        [19.8],
#        [ 9.7],
#        [16.4],
#        [10.7],
#        [22.6],
#        [21.2],
#        [20.2],
#        [23.7],
#        [ 5.5],
#        [13.2],
#        [23.8],
#        [18.4],
#        [ 8.1],
#        [24.2],
#        [20.7],
#        [14. ],
#        [16. ],
#        [11.3],
#        [11. ],
#        [13.4],
#        [18.9],
#        [22.3],
#        [18.3],
#        [12.4],
#        [ 8.8],
#        [11. ],
#        [17. ],
#        [ 8.7],
#        [ 6.9],
#        [14.2],
#        [ 5.3],
#        [11. ],
#        [11.8],
#        [17.3],
#        [11.3],
#        [13.6],
#        [21.7],
#        [20.2],
#        [12. ],
#        [16. ],
#        [12.9],
#        [16.7],
#        [14. ],
#        [ 7.3],
#        [19.4],
#        [22.2],
#        [11.5],
#        [16.9],
#        [16.7],
#        [20.5],
#        [25.4],
#        [17.2],
#        [16.7],
#        [23.8],
#        [19.8],
#        [19.7],
#        [20.7],
#        [15. ],
#        [ 7.2],
#        [12. ],
#        [ 5.3],
#        [19.8],
#        [18.4],
#        [21.8],
#        [17.1],
#        [20.9],
#        [14.6],
#        [12.6],
#        [12.2],
#        [ 9.4],
#        [15.9],
#        [ 6.6],
#        [15.5],
#        [ 7. ],
#        [16.6],
#        [15.2],
#        [19.7],
#        [10.6],
#        [ 6.6],
#        [11.9],
#        [24.7],
#        [ 9.7],
#        [ 1.6],
#        [17.7],
#        [ 5.7],
#        [19.6],
#        [10.8],
#        [11.6],
#        [ 9.5],
#        [20.8],
#        [ 9.6],
#        [20.7],
#        [10.9],
#        [19.2],
#        [20.1],
#        [10.4],
#        [12.3],
#        [10.3],
#        [18.2],
#        [25.4],
#        [10.9],
#        [10.1],
#        [16.1],
#        [11.6],
#        [16.6],
#        [16. ],
#        [20.6],
#        [ 3.2],
#        [15.3],
#        [10.1],
#        [ 7.3],
#        [12.9],
#        [16.4],
#        [13.3],
#        [19.9],
#        [18. ],
#        [11.9],
#        [16.9],
#        [ 8. ],
#        [17.2],
#        [17.1],
#        [20. ],
#        [ 8.4],
#        [17.5],
#        [ 7.6],
#        [16.7],
#        [16.5],
#        [27. ],
#        [20.2],
#        [16.7],
#        [16.8],
#        [17.6],
#        [15.5],
#        [17.2],
#        [ 8.7],
#        [26.2],
#        [17.6],
#        [22.6],
#        [10.3],
#        [17.3],
#        [20.9],
#        [ 6.7],
#        [10.8],
#        [11.9],
#        [ 5.9],
#        [19.6],
#        [17.3],
#        [ 7.6],
#        [14. ],
#        [14.8],
#        [25.5],
#        [18.4]])

# %% [markdown]
# $\widehat{\beta}=(X^{T}.X)^{-1}.X^{T}.Y$

# %%
# We can implement this using NumPy’s linalg module’s matrix inverse function and matrix multiplication function.
beta_hat = np.linalg.inv(X_mat.T.dot(X_mat)).dot(X_mat.T).dot(Y)

# %%
beta_hat
# Out:
# array([6.97482149, 0.05546477])
